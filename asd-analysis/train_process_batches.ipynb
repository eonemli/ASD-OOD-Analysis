# %%
import simpsom as sps
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import pickle

from collections import OrderedDict

scale = lambda x,a,b: (b-a)*(x-min(x))/(max(x)-min(x)) + a

# %matplotlib inline

# %%
with open('data_scorenorm/combined_data_score_norms_v3_cont_asd.pkl', 'rb') as file:
    combined_data = pickle.load(file)

# %%
score_norms_abcd_val = combined_data['score_norms']['abcd-val']
score_norms_abcd_test = combined_data['score_norms']['abcd-test']
score_norms_abcd_asd = combined_data['score_norms']['abcd-asd']
score_norms_conte = combined_data['score_norms']['conte']
score_norms_ibis_typical = combined_data['score_norms']['ibis-inlier']
score_norms_ibis_hr_typical = combined_data['score_norms']['ibis-hr-inliers']
score_norms_ibis_atypical = combined_data['score_norms']['ibis-atypical']
score_norms_ibis_asd = combined_data['score_norms']['ibis-asd']
score_norms_ibis_ds = combined_data['score_norms']['ibis-ds-sa']

# %%
score_norms_abcd = np.concatenate([score_norms_abcd_val, score_norms_abcd_test], axis=0)

score_norms_abcd.shape, score_norms_ibis_typical.shape
# Out:
# ((330, 1, 20), (82, 1, 20))

# %%
identifiers_abcd_val = combined_data['identifier']['abcd-val']
identifiers_abcd_test = combined_data['identifier']['abcd-test']
identifiers_abcd_asd = combined_data['identifier']['abcd-asd']
identifiers_conte = combined_data['identifier']['conte']
identifiers_ibis_typical = combined_data['identifier']['ibis-inlier']
identifiers_ibis_hr_typical = combined_data['identifier']['ibis-hr-inliers']
identifiers_ibis_atypical = combined_data['identifier']['ibis-atypical']
identifiers_ibis_asd = combined_data['identifier']['ibis-asd']
identifiers_ibis_ds = combined_data['identifier']['ibis-ds-sa']

identifiers_abcd = np.concatenate([identifiers_abcd_val, identifiers_abcd_test], axis=0)
identifiers_abcd.shape
# Out:
# (330,)

# %%
print('score_norms_abcd_val\t\t', score_norms_abcd_val.shape)
print('score_norms_abcd_test\t\t', score_norms_abcd_test.shape)
print('score_norms_abcd\t\t', score_norms_abcd.shape)
print('score_norms_abcd_asd\t\t', score_norms_abcd_asd.shape)
print('score_norms_conte\t\t', score_norms_conte.shape)
print('score_norms_ibis_typical\t', score_norms_ibis_typical.shape)
print('score_norms_ibis_hr_typical\t', score_norms_ibis_hr_typical.shape)
print('score_norms_ibis_atypical\t', score_norms_ibis_atypical.shape)
print('score_norms_ibis_asd\t\t', score_norms_ibis_asd.shape)
print('score_norms_ibis_ds\t\t', score_norms_ibis_ds.shape)
# Out:
# score_norms_abcd_val		 (165, 1, 20)
# score_norms_abcd_test		 (165, 1, 20)
# score_norms_abcd		 (330, 1, 20)
# score_norms_abcd_asd		 (161, 1, 20)
# score_norms_conte		 (444, 1, 20)
# score_norms_ibis_typical	 (82, 1, 20)
# score_norms_ibis_hr_typical	 (106, 1, 20)
# score_norms_ibis_atypical	 (38, 1, 20)
# score_norms_ibis_asd		 (65, 1, 20)
# score_norms_ibis_ds		 (28, 1, 20)

# %%
score_norms_abcd_val = np.squeeze(score_norms_abcd_val)
score_norms_abcd_test = np.squeeze(score_norms_abcd_test)
score_norms_abcd = np.squeeze(score_norms_abcd)
score_norms_abcd_asd = np.squeeze(score_norms_abcd_asd)
score_norms_conte = np.squeeze(score_norms_conte)
score_norms_ibis_typical = np.squeeze(score_norms_ibis_typical)
score_norms_ibis_hr_typical = np.squeeze(score_norms_ibis_hr_typical)
score_norms_ibis_atypical = np.squeeze(score_norms_ibis_atypical)
score_norms_ibis_asd = np.squeeze(score_norms_ibis_asd)
score_norms_ibis_ds = np.squeeze(score_norms_ibis_ds)

# %%
dataset_id_to_name = {-1: "ABCD", 0:"LR-Typical", 1:"HR-Typical", 2:"Atypical", 3:"Down Syndrome", 4:"IBIS-ASD", 5:"ABCD-ASD", 6:"Conte"}
dataset_name_to_id = {v:k for k,v in dataset_id_to_name.items()}
#dataset_list = [abcd_data, ibis_typical, ibis_hr_typical, ibis_atypical, ibis_ds, ibis_asd]
dataset_list = [score_norms_abcd, score_norms_ibis_typical, score_norms_ibis_hr_typical, score_norms_ibis_atypical, score_norms_ibis_ds, score_norms_ibis_asd, score_norms_abcd_asd, score_norms_conte]

X_data = np.concatenate(dataset_list, axis=0)
y_labels = np.concatenate([[i-1]*len(d) for i,d in enumerate(dataset_list)])

assert len(y_labels)==len(X_data)
# X_data = (X_data - np.mean(abcd_data, axis=0)) / np.std(abcd_data, axis=0)
inlier_data = X_data[y_labels <= 0]
test_data = X_data[y_labels > 0]
test_labels = y_labels[y_labels > 0]
train_labels = y_labels[y_labels <= 0]


mu, std = np.mean(inlier_data, axis=0), np.std(inlier_data, axis=0)
inlier_data = (inlier_data - mu) / std
test_data = (test_data  - mu) / std

dssamples = test_data[test_labels == dataset_name_to_id["ABCD-ASD"]]
X_data.shape, inlier_data.shape, len(dssamples), test_data.shape
# Out:
# ((1254, 20), (412, 20), 161, (842, 20))

# %%
identifiers_list = [identifiers_abcd, identifiers_ibis_typical, identifiers_ibis_hr_typical, identifiers_ibis_atypical, identifiers_ibis_ds, identifiers_ibis_asd, identifiers_abcd_asd, identifiers_conte]
indentifiers_data = np.concatenate(identifiers_list, axis=0)
inlier_identifiers = indentifiers_data[y_labels <= 0] 
test_identifiers = indentifiers_data[y_labels > 0]

# %% [markdown]
# ## Getting required Metadata for identifying and saving batches.

# %%
indentifiers_data.shape
# Out:
# (1254,)

# %%
indentifiers_data[-1]
# Out:
# 'TWINST0326-1-2'

# %%
identifiers_ibis_asd
# Out:
# ['IBIS845807',
#  'IBIS107524',
#  'IBIS903923',
#  'IBIS108131',
#  'IBIS868281',
#  'IBIS110925',
#  'IBIS910593',
#  'IBIS152174',
#  'IBIS919979',
#  'IBIS155712',
#  'IBIS929204',
#  'IBIS160209',
#  'IBIS973338',
#  'IBIS174982',
#  'IBIS983222',
#  'IBIS230955',
#  'IBIS988197',
#  'IBIS235108',
#  'IBIS988903',
#  'IBIS241033',
#  'IBIS291809',
#  'IBIS336576',
#  'IBIS373485',
#  'IBIS389101',
#  'IBIS389521',
#  'IBIS391729',
#  'IBIS396346',
#  'IBIS402809',
#  'IBIS439857',
#  'IBIS447754',
#  'IBIS456823',
#  'IBIS460612',
#  'IBIS463809',
#  'IBIS482642',
#  'IBIS490878',
#  'IBIS502237',
#  'IBIS515353',
#  'IBIS544847',
#  'IBIS552855',
#  'IBIS553295',
#  'IBIS569748',
#  'IBIS570637',
#  'IBIS597653',
#  'IBIS600014',
#  'IBIS603076',
#  'IBIS628043',
#  'IBIS638999',
#  'IBIS641078',
#  'IBIS649998',
#  'IBIS680028',
#  'IBIS688878',
#  'IBIS769060',
#  'IBIS784198',
#  'IBIS792433',
#  'IBIS809318',
#  'IBIS810826',
#  'IBIS816236',
#  'IBIS830319',
#  'IBIS841812',
#  'IBIS930203',
#  'IBIS931343',
#  'IBIS942002',
#  'IBIS943489',
#  'IBIS950194',
#  'IBIS963992']

# %%
ibis_metadata = pd.read_csv("spreadsheets/ibis_metadata_v2.csv")
ibis_metadata.index = ibis_metadata["CandID"].apply(lambda x: "IBIS" + str(x))
ibis_metadata.index.name = "ID"
ibis_metadata = ibis_metadata.astype(np.float32, errors="ignore")

# %%
list(ibis_metadata.columns)
# Out:
# ['Identifiers',
#  'V24 ADOS_Derived,restricted_repetitive_behavior_total',
#  'V36 ADOS_Derived,restricted_repetitive_behavior_total',
#  'V37Plus ADOS_Derived,restricted_repetitive_behavior_total',
#  'V24 ADOS_Derived,severity_score_lookup',
#  'V36 ADOS_Derived,severity_score_lookup',
#  'V37Plus ADOS_Derived,severity_score_lookup',
#  'V24 ADOS_Derived,social_affect_restricted_repetitive_behavior_total',
#  'V36 ADOS_Derived,social_affect_restricted_repetitive_behavior_total',
#  'V37Plus ADOS_Derived,social_affect_restricted_repetitive_behavior_total',
#  'V24 ADOS_Derived,social_affect_total',
#  'V36 ADOS_Derived,social_affect_total',
#  'V37Plus ADOS_Derived,social_affect_total',
#  'ASD_Latest_DSMIV',
#  'ASD_Latest_DSMV',
#  'CandID',
#  'VSA-Subtype',
#  'VSA DAS_SA,PC_ABILITY_SCORE',
#  'VSA DAS_SA,matrices_ABILITY_SCORE',
#  'VSA DAS_SA,rd_ABILITY_SCORE',
#  'VSA DAS_SA,seq_qr_ABILITY_SCORE',
#  'VSA DAS_SA,verbal_similarities_ABILITY_SCORE',
#  'VSA DAS_SA,word_defn_ABILITY_SCORE',
#  'Vineland-adapt_behave_comp_PERCENTILE',
#  'Vineland-adapt_behave_comp_STD_SCORE',
#  'Vineland-communication_PERCENTILE',
#  'Vineland-communication_STD_SCORE',
#  'Vineland-community_RAW_SCORE',
#  'Vineland-community_percent_estimated',
#  'Vineland-community_v_Scale_Score',
#  'Vineland-copy_skills_RAW_SCORE',
#  'Vineland-copy_skills_percent_estimated',
#  'Vineland-copy_skills_v_Scale_Score',
#  'Vineland-daily_living_skills_PERCENTILE',
#  'Vineland-daily_living_skills_STD_SCORE',
#  'Vineland-domestic_RAW_SCORE',
#  'Vineland-domestic_percent_estimated',
#  'Vineland-domestic_v_Scale_Score',
#  'Vineland-expressive_RAW_SCORE',
#  'Vineland-expressive_percent_estimated',
#  'Vineland-expressive_v_Scale_Score',
#  'Vineland-fine_motor_RAW_SCORE',
#  'Vineland-fine_motor_percent_estimated',
#  'Vineland-fine_motor_v_Scale_Score',
#  'Vineland-gross_motor_RAW_SCORE',
#  'Vineland-gross_motor_percent_estimated',
#  'Vineland-gross_motor_v_Scale_Score',
#  'Vineland-inter_pers_rel_RAW_SCORE',
#  'Vineland-inter_pers_rel_percent_estimated',
#  'Vineland-inter_pers_rel_v_Scale_Score',
#  'Vineland-motor_skills_PERCENTILE',
#  'Vineland-motor_skills_STD_SCORE',
#  'Vineland-personal_RAW_SCORE',
#  'Vineland-personal_percent_estimated',
#  'Vineland-personal_v_Scale_Score',
#  'Vineland-play_leisure_RAW_SCORE',
#  'Vineland-play_leisure_percent_estimated',
#  'Vineland-play_leisure_v_Scale_Score',
#  'Vineland-receptive_RAW_SCORE',
#  'Vineland-receptive_percent_estimated',
#  'Vineland-receptive_v_Scale_Score',
#  'Vineland-socialization_PERCENTILE',
#  'Vineland-socialization_STD_SCORE',
#  'Vineland-written_RAW_SCORE',
#  'Vineland-written_percent_estimated',
#  'Vineland-written_v_Scale_Score',
#  'CBCL-aggr_behav_T_score',
#  'CBCL-aggr_behav_percentile',
#  'CBCL-aggr_behav_score',
#  'CBCL-anx_prob_T_score',
#  'CBCL-anx_prob_percentile',
#  'CBCL-anx_prob_score',
#  'CBCL-anxious_T_score',
#  'CBCL-anxious_percentile',
#  'CBCL-anxious_score',
#  'CBCL-attention_hyper_prob_T_score',
#  'CBCL-attention_hyper_prob_percentile',
#  'CBCL-attention_hyper_prob_score',
#  'CBCL-attention_prob_T_score',
#  'CBCL-attention_prob_percentile',
#  'CBCL-attention_prob_score',
#  'CBCL-conduct_prob_T_score',
#  'CBCL-conduct_prob_percentile',
#  'CBCL-conduct_prob_score',
#  'CBCL-depressed_T_score',
#  'CBCL-depressed_percentile',
#  'CBCL-depressed_score',
#  'CBCL-depressive_prob_T_score',
#  'CBCL-depressive_prob_percentile',
#  'CBCL-depressive_prob_score',
#  'CBCL-externalizing_T_score',
#  'CBCL-externalizing_percentile',
#  'CBCL-externalizing_score',
#  'CBCL-internalizing_T_score',
#  'CBCL-internalizing_percentile',
#  'CBCL-internalizing_score',
#  'CBCL-obsessive_comp_prob_T_score',
#  'CBCL-obsessive_comp_prob_percentile',
#  'CBCL-obsessive_comp_prob_score',
#  'CBCL-oppo_def_prob_T_score',
#  'CBCL-oppo_def_prob_percentile',
#  'CBCL-oppo_def_prob_score',
#  'CBCL-rule_break_behav_T_score',
#  'CBCL-rule_break_behav_percentile',
#  'CBCL-rule_break_behav_score',
#  'CBCL-sluggish_cogn_tempo_T_score',
#  'CBCL-sluggish_cogn_tempo_percentile',
#  'CBCL-sluggish_cogn_tempo_score',
#  'CBCL-social_prob_T_score',
#  'CBCL-social_prob_percentile',
#  'CBCL-social_prob_score',
#  'CBCL-som_comp_T_score',
#  'CBCL-som_comp_percentile',
#  'CBCL-som_comp_score',
#  'CBCL-som_prob_T_score',
#  'CBCL-som_prob_percentile',
#  'CBCL-som_prob_score',
#  'CBCL-stress_prob_T_score',
#  'CBCL-stress_prob_percentile',
#  'CBCL-stress_prob_score',
#  'CBCL-thought_prob_T_score',
#  'CBCL-thought_prob_percentile',
#  'CBCL-thought_prob_score',
#  'CBCL-total_problems_T_score',
#  'CBCL-total_problems_percentile',
#  'CBCL-total_problems_score',
#  'Sex']

# %%
ibis_metadata
# Out:
#            Identifiers  V24 ADOS_Derived,restricted_repetitive_behavior_total  \
# ID
# IBIS389101     PHI0000                                                3.0
# IBIS-1         PHI0002                                                2.0
# IBIS769118     PHI0006                                                0.0
# IBIS638943     PHI0007                                                1.0
# IBIS929204     PHI0010                                                2.0
# ...                ...                                                ...
# IBIS346176     UNC1052                                               -1.0
# IBIS345986     UNC1053                                               -1.0
# IBIS490549     UNC1054                                               -1.0
# IBIS250626     UNC1055                                               -1.0
# IBIS233336     UNC1056                                               -1.0
#
#             V36 ADOS_Derived,restricted_repetitive_behavior_total  \
# ID
# IBIS389101                                                1.0
# IBIS-1                                                    6.0
# IBIS769118                                                1.0
# IBIS638943                                                2.0
# IBIS929204                                                2.0
# ...                                                       ...
# IBIS346176                                               -1.0
# IBIS345986                                               -1.0
# IBIS490549                                               -1.0
# IBIS250626                                               -1.0
# IBIS233336                                               -1.0
#
#             V37Plus ADOS_Derived,restricted_repetitive_behavior_total  \
# ID
# IBIS389101                                               -1.0
# IBIS-1                                                   -1.0
# IBIS769118                                               -1.0
# IBIS638943                                               -1.0
# IBIS929204                                               -1.0
# ...                                                       ...
# IBIS346176                                               -1.0
# IBIS345986                                               -1.0
# IBIS490549                                               -1.0
# IBIS250626                                               -1.0
# IBIS233336                                               -1.0
#
#             V24 ADOS_Derived,severity_score_lookup  \
# ID
# IBIS389101                                     8.0
# IBIS-1                                         8.0
# IBIS769118                                     1.0
# IBIS638943                                     2.0
# IBIS929204                                     7.0
# ...                                            ...
# IBIS346176                                    -1.0
# IBIS345986                                    -1.0
# IBIS490549                                    -1.0
# IBIS250626                                    -1.0
# IBIS233336                                    -1.0
#
#             V36 ADOS_Derived,severity_score_lookup  \
# ID
# IBIS389101                                     1.0
# IBIS-1                                        10.0
# IBIS769118                                     1.0
# IBIS638943                                     2.0
# IBIS929204                                     6.0
# ...                                            ...
# IBIS346176                                    -1.0
# IBIS345986                                    -1.0
# IBIS490549                                    -1.0
# IBIS250626                                    -1.0
# IBIS233336                                    -1.0
#
#             V37Plus ADOS_Derived,severity_score_lookup  \
# ID
# IBIS389101                                        -1.0
# IBIS-1                                            -1.0
# IBIS769118                                        -1.0
# IBIS638943                                        -1.0
# IBIS929204                                        -1.0
# ...                                                ...
# IBIS346176                                        -1.0
# IBIS345986                                        -1.0
# IBIS490549                                        -1.0
# IBIS250626                                        -1.0
# IBIS233336                                        -1.0
#
#             V24 ADOS_Derived,social_affect_restricted_repetitive_behavior_total  \
# ID
# IBIS389101                                               17.0
# IBIS-1                                                   17.0
# IBIS769118                                                3.0
# IBIS638943                                                4.0
# IBIS929204                                               16.0
# ...                                                       ...
# IBIS346176                                               -1.0
# IBIS345986                                               -1.0
# IBIS490549                                               -1.0
# IBIS250626                                               -1.0
# IBIS233336                                               -1.0
#
#             V36 ADOS_Derived,social_affect_restricted_repetitive_behavior_total  \
# ID
# IBIS389101                                                2.0
# IBIS-1                                                   20.0
# IBIS769118                                                2.0
# IBIS638943                                                5.0
# IBIS929204                                               12.0
# ...                                                       ...
# IBIS346176                                               -1.0
# IBIS345986                                               -1.0
# IBIS490549                                               -1.0
# IBIS250626                                               -1.0
# IBIS233336                                               -1.0
#
#             V37Plus ADOS_Derived,social_affect_restricted_repetitive_behavior_total  \
# ID
# IBIS389101                                               -1.0
# IBIS-1                                                   -1.0
# IBIS769118                                               -1.0
# IBIS638943                                               -1.0
# IBIS929204                                               -1.0
# ...                                                       ...
# IBIS346176                                               -1.0
# IBIS345986                                               -1.0
# IBIS490549                                               -1.0
# IBIS250626                                               -1.0
# IBIS233336                                               -1.0
#
#             ...  CBCL-stress_prob_T_score  CBCL-stress_prob_percentile  \
# ID          ...
# IBIS389101  ...                        -1                           -1
# IBIS-1      ...                        -1                           -1
# IBIS769118  ...                        50                           50
# IBIS638943  ...                        74                           99
# IBIS929204  ...                        57                           76
# ...         ...                       ...                          ...
# IBIS346176  ...                        -1                           -1
# IBIS345986  ...                        -1                           -1
# IBIS490549  ...                        -1                           -1
# IBIS250626  ...                        -1                           -1
# IBIS233336  ...                        -1                           -1
#
#             CBCL-stress_prob_score CBCL-thought_prob_T_score  \
# ID
# IBIS389101                    -1.0                        -1
# IBIS-1                        -1.0                        -1
# IBIS769118                     1.0                        51
# IBIS638943                    14.0                        64
# IBIS929204                     5.0                        54
# ...                            ...                       ...
# IBIS346176                    -1.0                        -1
# IBIS345986                    -1.0                        -1
# IBIS490549                    -1.0                        -1
# IBIS250626                    -1.0                        -1
# IBIS233336                    -1.0                        -1
#
#            CBCL-thought_prob_percentile  CBCL-thought_prob_score  \
# ID
# IBIS389101                           -1                     -1.0
# IBIS-1                               -1                     -1.0
# IBIS769118                           54                      1.0
# IBIS638943                           92                      5.0
# IBIS929204                           65                      2.0
# ...                                 ...                      ...
# IBIS346176                           -1                     -1.0
# IBIS345986                           -1                     -1.0
# IBIS490549                           -1                     -1.0
# IBIS250626                           -1                     -1.0
# IBIS233336                           -1                     -1.0
#
#            CBCL-total_problems_T_score  CBCL-total_problems_percentile  \
# ID
# IBIS389101                          -1                              -1
# IBIS-1                              -1                              -1
# IBIS769118                          40                              16
# IBIS638943                          71                              99
# IBIS929204                          57                              76
# ...                                ...                             ...
# IBIS346176                          -1                              -1
# IBIS345986                          -1                              -1
# IBIS490549                          -1                              -1
# IBIS250626                          -1                              -1
# IBIS233336                          -1                              -1
#
#             CBCL-total_problems_score   Sex
# ID
# IBIS389101                       -1.0  Male
# IBIS-1                           -1.0    -1
# IBIS769118                        6.0  Male
# IBIS638943                       71.0  Male
# IBIS929204                       34.0  Male
# ...                               ...   ...
# IBIS346176                       -1.0    -1
# IBIS345986                       -1.0    -1
# IBIS490549                       -1.0    -1
# IBIS250626                       -1.0    -1
# IBIS233336                       -1.0    -1
#
# [423 rows x 127 columns]

# %%
ibis_metadata['Sex'].unique() # There is -1
# Out:
# array(['Male', '-1', 'Female'], dtype=object)

# %%
VSADemographicsMar2023 = pd.read_csv("spreadsheets/VSADemographicsMar2023.csv")
VSADemographicsMar2023.index = VSADemographicsMar2023["VSA demographics,CandID"].apply(lambda x: "IBIS" + str(x))
VSADemographicsMar2023.index.name = "ID"
VSADemographicsMar2023 = VSADemographicsMar2023.astype(np.float32, errors="ignore")

# %%
VSADemographicsMar2023
# Out:
#             VSA demographics,CandID Identifiers  \
# ID
# IBIS103831                 103831.0     UNC0234
# IBIS105477                 105477.0     SEA4003
# IBIS105784                 105784.0     UNC0239
# IBIS107524                 107524.0     STL0200
# IBIS108131                 108131.0     SEA1006
# ...                             ...         ...
# IBIS988903                 988903.0     SEA0163
# IBIS989241                 989241.0     PHI4005
# IBIS992063                 992063.0     STL0003
# IBIS995004                 995004.0     STL0249
# IBIS999434                 999434.0     UNC1032
#
#            VSA demographics,ASD_Ever_DSMIV VSA demographics,ASD_Ever_DSMV  \
# ID
# IBIS103831      No DSMIV ever administered      No DSMV ever administered
# IBIS105477                            ASD-                           ASD-
# IBIS105784                 ASD+ (V24, V36)      No DSMV ever administered
# IBIS107524        ASD+ (V24, V36, VSA-CVD)            ASD+ (V36, VSA-CVD)
# IBIS108131                      ASD+ (V24)                     ASD+ (V24)
# ...                                    ...                            ...
# IBIS988903            ASD+ (V24, V36, VSA)                ASD+ (V36, VSA)
# IBIS989241                            ASD-                           ASD-
# IBIS992063                            ASD-                           ASD-
# IBIS995004                            ASD-                           ASD-
# IBIS999434                            ASD-                           ASD-
#
#             VSA demographics,Age_at_visit_start VSA demographics,Risk  \
# ID
# IBIS103831                                131.0                   NaN
# IBIS105477                                136.0                   NaN
# IBIS105784                                134.0                   NaN
# IBIS107524                                135.0                    HR
# IBIS108131                                 84.0                    HR
# ...                                         ...                   ...
# IBIS988903                                103.0                    HR
# IBIS989241                                 87.0                   NaN
# IBIS992063                                137.0                    HR
# IBIS995004                                128.0                    HR
# IBIS999434                                 91.0                    HR
#
#            VSA demographics,Sex VSA demographics,candidate_race
# ID
# IBIS103831                 Male                           white
# IBIS105477               Female                           white
# IBIS105784                 Male                             NaN
# IBIS107524                 Male                               0
# IBIS108131                 Male                           white
# ...                         ...                             ...
# IBIS988903                 Male                             NaN
# IBIS989241                 Male                           white
# IBIS992063               Female                             NaN
# IBIS995004               Female                               0
# IBIS999434               Female            unknown_not_reported
#
# [423 rows x 8 columns]

# %%
VSADemographicsMar2023["VSA demographics,Sex"].value_counts()
# Out:
# VSA demographics,Sex
# Male      253
# Female    170
# Name: count, dtype: int64

# %%
VSADemographicsMar2023["Identifiers"].apply(lambda x: x[:3]).value_counts()
# Out:
# Identifiers
# UNC    112
# STL    109
# SEA    107
# PHI     95
# Name: count, dtype: int64

# %%
# NOTE: Path in local: /.../ABCD/ABCD_5.1_Spreadsheets/core/imaging/mri_y_adm_info.csv
abcd_mri_y_adm_info = pd.read_csv("spreadsheets/mri_y_adm_info.csv")

# %%
abcd_mri_y_adm_info
# Out:
#          src_subject_id                 eventname           mri_info_visitid  \
# 0      NDAR_INV003RTV85     baseline_year_1_arm_1  S042_INV003RTV85_baseline
# 1      NDAR_INV005V6D2C     baseline_year_1_arm_1  G031_INV005V6D2C_baseline
# 2      NDAR_INV007W6H7B     baseline_year_1_arm_1  G054_INV007W6H7B_baseline
# 3      NDAR_INV00BD7VDC     baseline_year_1_arm_1  S090_INV00BD7VDC_baseline
# 4      NDAR_INV00CY2MDM  2_year_follow_up_y_arm_1     S021_INV00CY2MDM_2year
# ...                 ...                       ...                        ...
# 22934  NDAR_INVZZZNB0XC  4_year_follow_up_y_arm_1     S011_INVZZZNB0XC_4year
# 22935  NDAR_INVZZZNB0XC     baseline_year_1_arm_1  S011_INVZZZNB0XC_baseline
# 22936  NDAR_INVZZZP87KR  2_year_follow_up_y_arm_1     P023_INVZZZP87KR_2year
# 22937  NDAR_INVZZZP87KR  4_year_follow_up_y_arm_1     P023_INVZZZP87KR_4year
# 22938  NDAR_INVZZZP87KR     baseline_year_1_arm_1  P023_INVZZZP87KR_baseline
#
#          mri_info_manufacturer mri_info_manufacturersmn  \
# 0                      SIEMENS               Prisma_fit
# 1           GE MEDICAL SYSTEMS          DISCOVERY MR750
# 2           GE MEDICAL SYSTEMS          DISCOVERY MR750
# 3                      SIEMENS               Prisma_fit
# 4                      SIEMENS                   Prisma
# ...                        ...                      ...
# 22934                  SIEMENS                   Prisma
# 22935                  SIEMENS                   Prisma
# 22936  Philips Medical Systems                  Ingenia
# 22937  Philips Medical Systems                  Ingenia
# 22938  Philips Medical Systems                  Ingenia
#
#       mri_info_deviceserialnumber  mri_info_magneticfieldstrength  \
# 0                    HASH96a0c182                               3
# 1                    HASHe3ce02d3                               3
# 2                    HASH48f7cbc3                               3
# 3                    HASH65b39280                               3
# 4                    HASHd422be27                               3
# ...                           ...                             ...
# 22934                HASH5b0cf1bb                               3
# 22935                HASH5b0cf1bb                               3
# 22936                HASH5ac2b20b                               3
# 22937                HASH5ac2b20b                               3
# 22938                HASH5ac2b20b                               3
#
#                           mri_info_softwareversion  mri_info_studydate
# 0                                     syngo MR E11            20181001
# 1      27\LX\MR Software release:DV26.0_R01_1725.a            20180422
# 2      25\LX\MR Software release:DV25.0_R02_1549.b            20170224
# 3                                     syngo MR E11            20180612
# 4                                     syngo MR E11            20190615
# ...                                            ...                 ...
# 22934                                 syngo MR E11            20210205
# 22935                                 syngo MR E11            20170103
# 22936                                5.3.1\5.3.1.2            20190802
# 22937                                5.6.1\5.6.1.2            20210819
# 22938                                5.3.0\5.3.0.0            20170804
#
# [22939 rows x 9 columns]

# %%
# Step 1: Filter the dataframe for samples with eventname "baseline_year_1_arm_1"
abcd_mri_y_adm_info_baseline = abcd_mri_y_adm_info[abcd_mri_y_adm_info['eventname'] == 'baseline_year_1_arm_1']

# Step 2: Group by src_subject_id and extract a list of unique mri_info_manufacturer values for each subject
manufacturer_lists = abcd_mri_y_adm_info_baseline.groupby('src_subject_id')['mri_info_manufacturer'] \
    .agg(lambda x: list(pd.unique(x)))

# Step 3: Filter to keep only those src_subject_id entries with more than one unique manufacturer
inconsistent_ids = manufacturer_lists[manufacturer_lists.apply(lambda x: len(x) > 1)]

# Step 4: Display the results
print("src_subject_id with more than one mri_info_manufacturer for baseline_year_1_arm_1:")
for subject_id, manufacturers in inconsistent_ids.items():
    print(f"{subject_id}: {manufacturers}")
# Out:
# src_subject_id with more than one mri_info_manufacturer for baseline_year_1_arm_1:

# %%
abcd_mri_y_adm_info_baseline
# Out:
#          src_subject_id              eventname           mri_info_visitid  \
# 0      NDAR_INV003RTV85  baseline_year_1_arm_1  S042_INV003RTV85_baseline
# 1      NDAR_INV005V6D2C  baseline_year_1_arm_1  G031_INV005V6D2C_baseline
# 2      NDAR_INV007W6H7B  baseline_year_1_arm_1  G054_INV007W6H7B_baseline
# 3      NDAR_INV00BD7VDC  baseline_year_1_arm_1  S090_INV00BD7VDC_baseline
# 6      NDAR_INV00CY2MDM  baseline_year_1_arm_1  S021_INV00CY2MDM_baseline
# ...                 ...                    ...                        ...
# 22928  NDAR_INVZZNX6W2P  baseline_year_1_arm_1  S020_INVZZNX6W2P_baseline
# 22931  NDAR_INVZZPKBDAC  baseline_year_1_arm_1  S012_INVZZPKBDAC_baseline
# 22933  NDAR_INVZZZ2ALR6  baseline_year_1_arm_1  G010_INVZZZ2ALR6_baseline
# 22935  NDAR_INVZZZNB0XC  baseline_year_1_arm_1  S011_INVZZZNB0XC_baseline
# 22938  NDAR_INVZZZP87KR  baseline_year_1_arm_1  P023_INVZZZP87KR_baseline
#
#          mri_info_manufacturer mri_info_manufacturersmn  \
# 0                      SIEMENS               Prisma_fit
# 1           GE MEDICAL SYSTEMS          DISCOVERY MR750
# 2           GE MEDICAL SYSTEMS          DISCOVERY MR750
# 3                      SIEMENS               Prisma_fit
# 6                      SIEMENS                   Prisma
# ...                        ...                      ...
# 22928                  SIEMENS                   Prisma
# 22931                  SIEMENS               Prisma_fit
# 22933       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 22935                  SIEMENS                   Prisma
# 22938  Philips Medical Systems                  Ingenia
#
#       mri_info_deviceserialnumber  mri_info_magneticfieldstrength  \
# 0                    HASH96a0c182                               3
# 1                    HASHe3ce02d3                               3
# 2                    HASH48f7cbc3                               3
# 3                    HASH65b39280                               3
# 6                    HASHd422be27                               3
# ...                           ...                             ...
# 22928                HASH11ad4ed5                               3
# 22931                HASHe4f6957a                               3
# 22933                HASH5b2fcf80                               3
# 22935                HASH5b0cf1bb                               3
# 22938                HASH5ac2b20b                               3
#
#                           mri_info_softwareversion  mri_info_studydate
# 0                                     syngo MR E11            20181001
# 1      27\LX\MR Software release:DV26.0_R01_1725.a            20180422
# 2      25\LX\MR Software release:DV25.0_R02_1549.b            20170224
# 3                                     syngo MR E11            20180612
# 6                                     syngo MR E11            20170822
# ...                                            ...                 ...
# 22928                                 syngo MR E11            20170313
# 22931                                 syngo MR E11            20180120
# 22933  25\LX\MR Software release:DV25.0_R02_1549.b            20170615
# 22935                                 syngo MR E11            20170103
# 22938                                5.3.0\5.3.0.0            20170804
#
# [11771 rows x 9 columns]

# %%
abcd_mri_y_adm_info_baseline["mri_info_manufacturer"].value_counts()
# Out:
# mri_info_manufacturer
# SIEMENS                    7273
# GE MEDICAL SYSTEMS         2975
# Philips Medical Systems    1523
# Name: count, dtype: int64

# %%
abcd_mri_y_adm_info_baseline["mri_info_manufacturersmn"].value_counts()
# Out:
# mri_info_manufacturersmn
# Prisma_fit         4213
# Prisma             3060
# DISCOVERY MR750    2974
# Achieva dStream     981
# Ingenia             542
# Orchestra SDK         1
# Name: count, dtype: int64

# %%
abcd_mri_y_adm_info["mri_info_manufacturersmn"].value_counts()
# Out:
# mri_info_manufacturersmn
# Prisma_fit         7538
# Prisma             6576
# DISCOVERY MR750    5914
# Achieva dStream    1743
# Ingenia            1040
# SIGNA Premier        83
# SIGNA UHP            44
# Orchestra SDK         1
# Name: count, dtype: int64

# %%
abcd_p_demo = pd.read_csv("/BEE/Connectome/ABCD/ABCD_5.1_Spreadsheets/core/abcd-general/abcd_p_demo.csv")

# %%
abcd_p_demo
# Out:
#          src_subject_id                 eventname  \
# 0      NDAR_INV003RTV85     baseline_year_1_arm_1
# 1      NDAR_INV003RTV85  1_year_follow_up_y_arm_1
# 2      NDAR_INV003RTV85  2_year_follow_up_y_arm_1
# 3      NDAR_INV003RTV85  3_year_follow_up_y_arm_1
# 4      NDAR_INV005V6D2C     baseline_year_1_arm_1
# ...                 ...                       ...
# 48802  NDAR_INVZZZP87KR     baseline_year_1_arm_1
# 48803  NDAR_INVZZZP87KR  1_year_follow_up_y_arm_1
# 48804  NDAR_INVZZZP87KR  2_year_follow_up_y_arm_1
# 48805  NDAR_INVZZZP87KR  3_year_follow_up_y_arm_1
# 48806  NDAR_INVZZZP87KR  4_year_follow_up_y_arm_1
#
#        demoi_p_select_language___1  demo_prim  demo_brthdat_v2  demo_ed_v2  \
# 0                                0        1.0             10.0         5.0
# 1                                0        NaN              NaN         NaN
# 2                                0        NaN              NaN         NaN
# 3                                0        NaN              NaN         NaN
# 4                                1        1.0             10.0         4.0
# ...                            ...        ...              ...         ...
# 48802                            0        1.0             10.0         5.0
# 48803                            0        NaN              NaN         NaN
# 48804                            0        NaN              NaN         NaN
# 48805                            0        NaN              NaN         NaN
# 48806                            0        NaN              NaN         NaN
#
#        demo_adopt_agex_v2  demo_adopt_agex_v2_bl_dk  demo_sex_v2  \
# 0                     NaN                       NaN          2.0
# 1                     NaN                       NaN          NaN
# 2                     NaN                       NaN          NaN
# 3                     NaN                       NaN          NaN
# 4                     NaN                       NaN          2.0
# ...                   ...                       ...          ...
# 48802                 NaN                       NaN          2.0
# 48803                 NaN                       NaN          NaN
# 48804                 NaN                       NaN          NaN
# 48805                 NaN                       NaN          NaN
# 48806                 NaN                       NaN          NaN
#
#        demo_gender_id_v2  ...  demo_nat_lang_3_yrs_other_p_14  \
# 0                    2.0  ...                             NaN
# 1                    NaN  ...                             NaN
# 2                    NaN  ...                             NaN
# 3                    NaN  ...                             NaN
# 4                    2.0  ...                             NaN
# ...                  ...  ...                             ...
# 48802                2.0  ...                             NaN
# 48803                NaN  ...                             NaN
# 48804                NaN  ...                             NaN
# 48805                NaN  ...                             NaN
# 48806                NaN  ...                             NaN
#
#        demo_nat_lang_3_p  demo_nat_lang_3_yrs_eng_p___1  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    0.0                            NaN
# 4                    NaN                            NaN
# ...                  ...                            ...
# 48802                NaN                            NaN
# 48803                NaN                            NaN
# 48804                NaN                            NaN
# 48805                0.0                            NaN
# 48806                0.0                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___2  demo_nat_lang_3_yrs_eng_p___3  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 48802                            NaN                            NaN
# 48803                            NaN                            NaN
# 48804                            NaN                            NaN
# 48805                            NaN                            NaN
# 48806                            NaN                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___4  demo_nat_lang_3_yrs_eng_p___5  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 48802                            NaN                            NaN
# 48803                            NaN                            NaN
# 48804                            NaN                            NaN
# 48805                            NaN                            NaN
# 48806                            NaN                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___6  race_ethnicity  \
# 0                                NaN             1.0
# 1                                NaN             1.0
# 2                                NaN             NaN
# 3                                NaN             NaN
# 4                                NaN             3.0
# ...                              ...             ...
# 48802                            NaN             2.0
# 48803                            NaN             2.0
# 48804                            NaN             NaN
# 48805                            NaN             NaN
# 48806                            NaN             NaN
#
#        acs_raked_propensity_score
# 0                      466.092707
# 1                      533.381820
# 2                             NaN
# 3                             NaN
# 4                      520.488325
# ...                           ...
# 48802                  835.604891
# 48803                  842.080358
# 48804                         NaN
# 48805                         NaN
# 48806                         NaN
#
# [48807 rows x 276 columns]

# %%
abcd_p_demo_baseline = abcd_p_demo[abcd_p_demo['eventname'] == 'baseline_year_1_arm_1']

# %%
abcd_p_demo_baseline
# Out:
#          src_subject_id              eventname  demoi_p_select_language___1  \
# 0      NDAR_INV003RTV85  baseline_year_1_arm_1                            0
# 4      NDAR_INV005V6D2C  baseline_year_1_arm_1                            1
# 8      NDAR_INV007W6H7B  baseline_year_1_arm_1                            0
# 11     NDAR_INV00BD7VDC  baseline_year_1_arm_1                            0
# 14     NDAR_INV00CY2MDM  baseline_year_1_arm_1                            0
# ...                 ...                    ...                          ...
# 48785  NDAR_INVZZNX6W2P  baseline_year_1_arm_1                            0
# 48790  NDAR_INVZZPKBDAC  baseline_year_1_arm_1                            0
# 48795  NDAR_INVZZZ2ALR6  baseline_year_1_arm_1                            0
# 48800  NDAR_INVZZZNB0XC  baseline_year_1_arm_1                            0
# 48802  NDAR_INVZZZP87KR  baseline_year_1_arm_1                            0
#
#        demo_prim  demo_brthdat_v2  demo_ed_v2  demo_adopt_agex_v2  \
# 0            1.0             10.0         5.0                 NaN
# 4            1.0             10.0         4.0                 NaN
# 8            2.0             10.0         4.0                 NaN
# 11           1.0              9.0         4.0                 NaN
# 14           1.0             10.0         5.0                 NaN
# ...          ...              ...         ...                 ...
# 48785        1.0             10.0         5.0                 NaN
# 48790        2.0              9.0         4.0                 NaN
# 48795        2.0             10.0         5.0                 NaN
# 48800        1.0              9.0         3.0                 NaN
# 48802        1.0             10.0         5.0                 NaN
#
#        demo_adopt_agex_v2_bl_dk  demo_sex_v2  demo_gender_id_v2  ...  \
# 0                           NaN          2.0                2.0  ...
# 4                           NaN          2.0                2.0  ...
# 8                           NaN          1.0                1.0  ...
# 11                          NaN          1.0                1.0  ...
# 14                          NaN          1.0                1.0  ...
# ...                         ...          ...                ...  ...
# 48785                       NaN          1.0                1.0  ...
# 48790                       NaN          2.0                2.0  ...
# 48795                       NaN          2.0                2.0  ...
# 48800                       NaN          2.0                2.0  ...
# 48802                       NaN          2.0                2.0  ...
#
#        demo_nat_lang_3_yrs_other_p_14  demo_nat_lang_3_p  \
# 0                                 NaN                NaN
# 4                                 NaN                NaN
# 8                                 NaN                NaN
# 11                                NaN                NaN
# 14                                NaN                NaN
# ...                               ...                ...
# 48785                             NaN                NaN
# 48790                             NaN                NaN
# 48795                             NaN                NaN
# 48800                             NaN                NaN
# 48802                             NaN                NaN
#
#        demo_nat_lang_3_yrs_eng_p___1  demo_nat_lang_3_yrs_eng_p___2  \
# 0                                NaN                            NaN
# 4                                NaN                            NaN
# 8                                NaN                            NaN
# 11                               NaN                            NaN
# 14                               NaN                            NaN
# ...                              ...                            ...
# 48785                            NaN                            NaN
# 48790                            NaN                            NaN
# 48795                            NaN                            NaN
# 48800                            NaN                            NaN
# 48802                            NaN                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___3  demo_nat_lang_3_yrs_eng_p___4  \
# 0                                NaN                            NaN
# 4                                NaN                            NaN
# 8                                NaN                            NaN
# 11                               NaN                            NaN
# 14                               NaN                            NaN
# ...                              ...                            ...
# 48785                            NaN                            NaN
# 48790                            NaN                            NaN
# 48795                            NaN                            NaN
# 48800                            NaN                            NaN
# 48802                            NaN                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___5  demo_nat_lang_3_yrs_eng_p___6  \
# 0                                NaN                            NaN
# 4                                NaN                            NaN
# 8                                NaN                            NaN
# 11                               NaN                            NaN
# 14                               NaN                            NaN
# ...                              ...                            ...
# 48785                            NaN                            NaN
# 48790                            NaN                            NaN
# 48795                            NaN                            NaN
# 48800                            NaN                            NaN
# 48802                            NaN                            NaN
#
#        race_ethnicity  acs_raked_propensity_score
# 0                 1.0                  466.092707
# 4                 3.0                  520.488325
# 8                 1.0                  479.185338
# 11                1.0                  414.643009
# 14                1.0                 1433.061575
# ...               ...                         ...
# 48785             1.0                  593.431278
# 48790             1.0                  568.508011
# 48795             5.0                  164.792483
# 48800             3.0                 1119.800572
# 48802             2.0                  835.604891
#
# [11868 rows x 276 columns]

# %%
abcd_p_demo_baseline['demo_sex_v2'].value_counts()
# Out:
# demo_sex_v2
# 1.0    6188
# 2.0    5677
# 3.0       3
# Name: count, dtype: int64

# %%
len(identifiers_ibis_asd), len(identifiers_abcd_asd)
# Out:
# (65, 161)

# %%
import pandas as pd

# --- Step 1: Remove underscores from src_subject_id in AB-CD baseline DataFrames ---
# Make an explicit copy:
abcd_mri_y_adm_info_baseline_ = abcd_mri_y_adm_info_baseline.copy()
# Remove underscores in abcd_mri_y_adm_info_baseline
abcd_mri_y_adm_info_baseline_.loc[:, 'src_subject_id'] = abcd_mri_y_adm_info_baseline_['src_subject_id'].str.replace('_', '')

# Remove underscores in abcd_p_demo_baseline
abcd_p_demo_baseline_ = abcd_p_demo_baseline.copy()
abcd_p_demo_baseline_.loc[:, 'src_subject_id'] = abcd_p_demo_baseline_['src_subject_id'].str.replace('_', '')

# --- Step 2: Filter rows based on identifiers_abcd_asd list ---
# identifiers_abcd_asd should be a list of IDs that match the cleaned src_subject_id values

abcd_mri_filtered = abcd_mri_y_adm_info_baseline_[
    abcd_mri_y_adm_info_baseline_['src_subject_id'].isin(identifiers_abcd_asd)
]

abcd_p_demo_filtered = abcd_p_demo_baseline_[
    abcd_p_demo_baseline_['src_subject_id'].isin(identifiers_abcd_asd)
]

# --- Step 3: Merge the filtered AB-CD dataframes, select columns, and convert demo_sex_v2 values ---
# Merge the two filtered dataframes on 'src_subject_id'
merged_abcd = pd.merge(abcd_mri_filtered, abcd_p_demo_filtered, on='src_subject_id', how='inner')

# Select only the columns of interest
merged_abcd = merged_abcd[['src_subject_id', 'mri_info_manufacturer', 'mri_info_manufacturersmn', 'demo_sex_v2']]

# Map numeric demo_sex_v2 values to gender labels
sex_mapping = {1: "Male", 2: "Female", 3: "Other"}
merged_abcd['demo_sex_v2'] = merged_abcd['demo_sex_v2'].map(sex_mapping)

# --- Step 4: Create a new dataframe from VSADemographicsMar2023 ---
# Since 'ID' is the index in VSADemographicsMar2023, we use the index for filtering.
# Filter the rows using the index (which holds the IDs)
vsa_filtered = VSADemographicsMar2023[VSADemographicsMar2023.index.isin(identifiers_ibis_asd)].copy()

# Reset the index so that 'ID' becomes a column
vsa_filtered.reset_index(inplace=True)

# Create a new column that holds only the first 3 characters of the 'Identifiers' column.
vsa_filtered['Identifiers_first3'] = vsa_filtered['Identifiers'].str[:3]

# Select only the desired columns: 'ID', new 'Identifiers_first3', and 'VSA demographics,Sex'
vsa_final = vsa_filtered[['ID', 'Identifiers_first3', 'VSA demographics,Sex']]

# %%
#identifiers_ibis_typical

# --- Step 4: Create a new dataframe from VSADemographicsMar2023 ---
# Since 'ID' is the index in VSADemographicsMar2023, we use the index for filtering.
# Filter the rows using the index (which holds the IDs)
vsa_filtered = VSADemographicsMar2023[VSADemographicsMar2023.index.isin(identifiers_ibis_typical)].copy()

# Reset the index so that 'ID' becomes a column
vsa_filtered.reset_index(inplace=True)

# Create a new column that holds only the first 3 characters of the 'Identifiers' column.
vsa_filtered['Identifiers_first3'] = vsa_filtered['Identifiers'].str[:3]

# Select only the desired columns: 'ID', new 'Identifiers_first3', and 'VSA demographics,Sex'
vsa_final_inliers = vsa_filtered[['ID', 'Identifiers_first3', 'VSA demographics,Sex']]

# %%
vsa_final_inliers.shape
# Out:
# (82, 3)

# %%
#vsa_final_inliers.to_csv("batches/batches_ibis_inlier_cols_site_sex.csv", index=False)

# %%
merged_abcd.head(10)
# Out:
#     src_subject_id    mri_info_manufacturer mri_info_manufacturersmn  \
# 0  NDARINV0182J779                  SIEMENS               Prisma_fit
# 1  NDARINV03KMHMJJ                  SIEMENS               Prisma_fit
# 2  NDARINV09AUXBBT       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 3  NDARINV0H2AWWPU       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 4  NDARINV0N0JE94U                  SIEMENS               Prisma_fit
# 5  NDARINV11THDW9B  Philips Medical Systems          Achieva dStream
# 6  NDARINV13BCLD41       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 7  NDARINV13FP25D3       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 8  NDARINV19GP5HLJ                  SIEMENS                   Prisma
# 9  NDARINV1ETGGL9R       GE MEDICAL SYSTEMS          DISCOVERY MR750
#
#   demo_sex_v2
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4        Male
# 5      Female
# 6        Male
# 7        Male
# 8        Male
# 9        Male

# %%
vsa_final.head(10)
# Out:
#            ID Identifiers_first3 VSA demographics,Sex
# 0  IBIS107524                STL                 Male
# 1  IBIS108131                SEA                 Male
# 2  IBIS110925                SEA                 Male
# 3  IBIS152174                SEA                 Male
# 4  IBIS155712                UNC                 Male
# 5  IBIS160209                PHI                 Male
# 6  IBIS174982                UNC                 Male
# 7  IBIS230955                PHI                 Male
# 8  IBIS235108                SEA               Female
# 9  IBIS241033                UNC                 Male

# %%
# merged_abcd.to_csv("batches/batches_abcd_asd_cols_scanner_model_sex.csv", index=False)
# vsa_final.to_csv("batches/batches_ibis_asd_cols_site_sex.csv", index=False)

# %% [markdown]
# ## Batches v2: inliers

# %%
# Step 1: Filter the dataframe for samples with eventname "baseline_year_1_arm_1"
abcd_mri_y_adm_info_baseline = abcd_mri_y_adm_info[abcd_mri_y_adm_info['eventname'] == 'baseline_year_1_arm_1']

# Step 2: Group by src_subject_id and extract a list of unique mri_info_manufacturer values for each subject
manufacturer_lists = abcd_mri_y_adm_info_baseline.groupby('src_subject_id')['mri_info_manufacturer'] \
    .agg(lambda x: list(pd.unique(x)))

# Step 3: Filter to keep only those src_subject_id entries with more than one unique manufacturer
inconsistent_ids = manufacturer_lists[manufacturer_lists.apply(lambda x: len(x) > 1)]

# Step 4: Display the results
print("src_subject_id with more than one mri_info_manufacturer for baseline_year_1_arm_1:")
for subject_id, manufacturers in inconsistent_ids.items():
    print(f"{subject_id}: {manufacturers}")
# Out:
# src_subject_id with more than one mri_info_manufacturer for baseline_year_1_arm_1:

# %%
abcd_p_demo
# Out:
#          src_subject_id                 eventname  \
# 0      NDAR_INV003RTV85     baseline_year_1_arm_1
# 1      NDAR_INV003RTV85  1_year_follow_up_y_arm_1
# 2      NDAR_INV003RTV85  2_year_follow_up_y_arm_1
# 3      NDAR_INV003RTV85  3_year_follow_up_y_arm_1
# 4      NDAR_INV005V6D2C     baseline_year_1_arm_1
# ...                 ...                       ...
# 48802  NDAR_INVZZZP87KR     baseline_year_1_arm_1
# 48803  NDAR_INVZZZP87KR  1_year_follow_up_y_arm_1
# 48804  NDAR_INVZZZP87KR  2_year_follow_up_y_arm_1
# 48805  NDAR_INVZZZP87KR  3_year_follow_up_y_arm_1
# 48806  NDAR_INVZZZP87KR  4_year_follow_up_y_arm_1
#
#        demoi_p_select_language___1  demo_prim  demo_brthdat_v2  demo_ed_v2  \
# 0                                0        1.0             10.0         5.0
# 1                                0        NaN              NaN         NaN
# 2                                0        NaN              NaN         NaN
# 3                                0        NaN              NaN         NaN
# 4                                1        1.0             10.0         4.0
# ...                            ...        ...              ...         ...
# 48802                            0        1.0             10.0         5.0
# 48803                            0        NaN              NaN         NaN
# 48804                            0        NaN              NaN         NaN
# 48805                            0        NaN              NaN         NaN
# 48806                            0        NaN              NaN         NaN
#
#        demo_adopt_agex_v2  demo_adopt_agex_v2_bl_dk  demo_sex_v2  \
# 0                     NaN                       NaN          2.0
# 1                     NaN                       NaN          NaN
# 2                     NaN                       NaN          NaN
# 3                     NaN                       NaN          NaN
# 4                     NaN                       NaN          2.0
# ...                   ...                       ...          ...
# 48802                 NaN                       NaN          2.0
# 48803                 NaN                       NaN          NaN
# 48804                 NaN                       NaN          NaN
# 48805                 NaN                       NaN          NaN
# 48806                 NaN                       NaN          NaN
#
#        demo_gender_id_v2  ...  demo_nat_lang_3_yrs_other_p_14  \
# 0                    2.0  ...                             NaN
# 1                    NaN  ...                             NaN
# 2                    NaN  ...                             NaN
# 3                    NaN  ...                             NaN
# 4                    2.0  ...                             NaN
# ...                  ...  ...                             ...
# 48802                2.0  ...                             NaN
# 48803                NaN  ...                             NaN
# 48804                NaN  ...                             NaN
# 48805                NaN  ...                             NaN
# 48806                NaN  ...                             NaN
#
#        demo_nat_lang_3_p  demo_nat_lang_3_yrs_eng_p___1  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    0.0                            NaN
# 4                    NaN                            NaN
# ...                  ...                            ...
# 48802                NaN                            NaN
# 48803                NaN                            NaN
# 48804                NaN                            NaN
# 48805                0.0                            NaN
# 48806                0.0                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___2  demo_nat_lang_3_yrs_eng_p___3  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 48802                            NaN                            NaN
# 48803                            NaN                            NaN
# 48804                            NaN                            NaN
# 48805                            NaN                            NaN
# 48806                            NaN                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___4  demo_nat_lang_3_yrs_eng_p___5  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 48802                            NaN                            NaN
# 48803                            NaN                            NaN
# 48804                            NaN                            NaN
# 48805                            NaN                            NaN
# 48806                            NaN                            NaN
#
#        demo_nat_lang_3_yrs_eng_p___6  race_ethnicity  \
# 0                                NaN             1.0
# 1                                NaN             1.0
# 2                                NaN             NaN
# 3                                NaN             NaN
# 4                                NaN             3.0
# ...                              ...             ...
# 48802                            NaN             2.0
# 48803                            NaN             2.0
# 48804                            NaN             NaN
# 48805                            NaN             NaN
# 48806                            NaN             NaN
#
#        acs_raked_propensity_score
# 0                      466.092707
# 1                      533.381820
# 2                             NaN
# 3                             NaN
# 4                      520.488325
# ...                           ...
# 48802                  835.604891
# 48803                  842.080358
# 48804                         NaN
# 48805                         NaN
# 48806                         NaN
#
# [48807 rows x 276 columns]

# %%
abcd_mri_y_adm_info[
    abcd_mri_y_adm_info['src_subject_id'].str.startswith('HC')]
# Out:
# Empty DataFrame
# Columns: [src_subject_id, eventname, mri_info_visitid, mri_info_manufacturer, mri_info_manufacturersmn, mri_info_deviceserialnumber, mri_info_magneticfieldstrength, mri_info_softwareversion, mri_info_studydate]
# Index: []

# %%
count_HCD = len([item for item in identifiers_abcd_val if item.startswith("HCD")])
print(count_HCD)
# Out:
# 37

# %%
abcd_mri_y_adm_info[
    abcd_mri_y_adm_info['src_subject_id'].str.startswith('NDAR_INVRR2')]
# Out:
#          src_subject_id                 eventname           mri_info_visitid  \
# 17823  NDAR_INVRR22WRZJ  2_year_follow_up_y_arm_1     S086_INVRR22WRZJ_2year
# 17824  NDAR_INVRR22WRZJ     baseline_year_1_arm_1  S086_INVRR22WRZJ_baseline
#
#       mri_info_manufacturer mri_info_manufacturersmn  \
# 17823               SIEMENS               Prisma_fit
# 17824               SIEMENS               Prisma_fit
#
#       mri_info_deviceserialnumber  mri_info_magneticfieldstrength  \
# 17823                HASH311170b9                               3
# 17824                HASH311170b9                               3
#
#       mri_info_softwareversion  mri_info_studydate
# 17823             syngo MR E11            20201118
# 17824             syngo MR E11            20181012

# %%
[item for item in identifiers_abcd_test if item.startswith("HCD")]
# Out:
# ['HCD0059235',
#  'HCD0124725',
#  'HCD0295954',
#  'HCD0353538',
#  'HCD0515538',
#  'HCD0621638',
#  'HCD0644044',
#  'HCD0684460',
#  'HCD0717954',
#  'HCD0758867',
#  'HCD0772255',
#  'HCD0797877',
#  'HCD0848969',
#  'HCD0869371',
#  'HCD1010311',
#  'HCD1017729',
#  'HCD1071836',
#  'HCD1108833',
#  'HCD1231832',
#  'HCD1239343',
#  'HCD1262136',
#  'HCD1400728',
#  'HCD1410933',
#  'HCD1529756',
#  'HCD1594767',
#  'HCD1742958',
#  'HCD1749467',
#  'HCD1886275',
#  'HCD1900142',
#  'HCD2035837',
#  'HCD2055237',
#  'HCD2229547',
#  'HCD2540648',
#  'HCD2606652',
#  'HCD2633554',
#  'HCD2635659',
#  'HCD2685169',
#  'HCD2711649',
#  'HCD2731049',
#  'HCD2737869']

# %%
[item for item in identifiers_abcd if item.startswith("NDAR_INVLP523WFQ")]
# Out:
# []

# %%
abcd_p_demo_baseline = abcd_p_demo[abcd_p_demo['eventname'] == 'baseline_year_1_arm_1']

# %%
import pandas as pd

# --- Step 1: Remove underscores from src_subject_id in AB-CD baseline DataFrames ---
# Make an explicit copy:
abcd_mri_y_adm_info_baseline_ = abcd_mri_y_adm_info_baseline.copy()
# Remove underscores in abcd_mri_y_adm_info_baseline
abcd_mri_y_adm_info_baseline_.loc[:, 'src_subject_id'] = abcd_mri_y_adm_info_baseline_['src_subject_id'].str.replace('_', '')

# Remove underscores in abcd_p_demo_baseline
abcd_p_demo_baseline_ = abcd_p_demo_baseline.copy()
abcd_p_demo_baseline_.loc[:, 'src_subject_id'] = abcd_p_demo_baseline_['src_subject_id'].str.replace('_', '')

# --- Step 2: Filter rows based on identifiers_abcd_asd list ---
# identifiers_abcd_asd should be a list of IDs that match the cleaned src_subject_id values

abcd_mri_filtered_inl = abcd_mri_y_adm_info_baseline_[
    abcd_mri_y_adm_info_baseline_['src_subject_id'].isin(identifiers_abcd)
]

abcd_p_demo_filtered_inl = abcd_p_demo_baseline_[
    abcd_p_demo_baseline_['src_subject_id'].isin(identifiers_abcd)
]

# --- Step 3: Merge the filtered AB-CD dataframes, select columns, and convert demo_sex_v2 values ---
# Merge the two filtered dataframes on 'src_subject_id'
merged2_abcd = pd.merge(abcd_mri_filtered_inl, abcd_p_demo_filtered_inl, on='src_subject_id', how='outer')

# Select only the columns of interest
merged2_abcd = merged2_abcd[['src_subject_id', 'mri_info_manufacturer', 'mri_info_manufacturersmn', 'demo_sex_v2']]

# Map numeric demo_sex_v2 values to gender labels
sex_mapping = {1: "Male", 2: "Female", 3: "Other"}
merged2_abcd['demo_sex_v2'] = merged2_abcd['demo_sex_v2'].map(sex_mapping)

# %%
#merged2_abcd.to_csv("batches/batches_abcd_inlier_cols_scanner_model_sex.csv", index=False)

# %%
abcd_mri_filtered_inl.shape, abcd_p_demo_filtered_inl.shape
# Out:
# ((251, 9), (252, 276))

# %%
merged2_abcd.head(20)
# Out:
#      src_subject_id    mri_info_manufacturer mri_info_manufacturersmn  \
# 0   NDARINV021403LF                  SIEMENS               Prisma_fit
# 1   NDARINV08P1JKNE  Philips Medical Systems          Achieva dStream
# 2   NDARINV0G37YGY1  Philips Medical Systems          Achieva dStream
# 3   NDARINV0PJ81CA5                  SIEMENS               Prisma_fit
# 4   NDARINV0RB5CTN0                  SIEMENS               Prisma_fit
# 5   NDARINV0UV5WZUN                  SIEMENS               Prisma_fit
# 6   NDARINV0V1TNU11                  SIEMENS               Prisma_fit
# 7   NDARINV0YVKYMJX       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 8   NDARINV0ZHHWCMZ                  SIEMENS               Prisma_fit
# 9   NDARINV10FDVE0L                  SIEMENS                   Prisma
# 10  NDARINV11G4DZFX       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 11  NDARINV137Y0WR8                  SIEMENS                   Prisma
# 12  NDARINV1BUXN6LH                  SIEMENS                   Prisma
# 13  NDARINV1F6MVGKL                  SIEMENS               Prisma_fit
# 14  NDARINV1FGX3DL8       GE MEDICAL SYSTEMS          DISCOVERY MR750
# 15  NDARINV1GDLVYHH                  SIEMENS                   Prisma
# 16  NDARINV1JZ17724                  SIEMENS               Prisma_fit
# 17  NDARINV1LX1A3TR                  SIEMENS               Prisma_fit
# 18  NDARINV1M0VVR9Y                  SIEMENS                   Prisma
# 19  NDARINV21VH8BF0                  SIEMENS                   Prisma
#
#    demo_sex_v2
# 0         Male
# 1         Male
# 2         Male
# 3       Female
# 4       Female
# 5         Male
# 6         Male
# 7         Male
# 8         Male
# 9       Female
# 10      Female
# 11      Female
# 12      Female
# 13      Female
# 14        Male
# 15      Female
# 16      Female
# 17        Male
# 18        Male
# 19        Male

# %%
merged2_abcd.shape
# Out:
# (252, 4)

# %%
merged_abcd.shape
# Out:
# (161, 4)

# %%
identifiers_abcd_asd_inlier_plus_asd_intersecton = list(set(identifiers_abcd_asd).intersection(identifiers_abcd))
identifiers_abcd_asd_inlier_plus_asd_intersecton
# Out:
# ['NDARINVNHL7P38J', 'NDARINVD0KNT1VK']

# %% [markdown]
# ### ABCD - Train batches

# %%
identifiers_abcd_train_path = "../asd-preprocessing/identifier_keys/split-keys/abcd-train_keys.txt"
identifiers_abcd_train_df = pd.read_csv(identifiers_abcd_train_path, header=None)
identifiers_abcd_train = identifiers_abcd_train_df[0].tolist()

# %%
# --- Step 1: Remove underscores from src_subject_id in ABCD baseline DataFrames ---
# Make an explicit copy:
abcd_mri_y_adm_info_baseline_ = abcd_mri_y_adm_info_baseline.copy()
# Remove underscores in abcd_mri_y_adm_info_baseline
abcd_mri_y_adm_info_baseline_.loc[:, 'src_subject_id'] = abcd_mri_y_adm_info_baseline_['src_subject_id'].str.replace('_', '')

# Remove underscores in abcd_p_demo_baseline
abcd_p_demo_baseline_ = abcd_p_demo_baseline.copy()
abcd_p_demo_baseline_.loc[:, 'src_subject_id'] = abcd_p_demo_baseline_['src_subject_id'].str.replace('_', '')

# --- Step 2: Filter rows based on identifiers_abcd_asd list ---
# identifiers_abcd_asd should be a list of IDs that match the cleaned src_subject_id values

abcd_mri_filtered_tr = abcd_mri_y_adm_info_baseline_[
    abcd_mri_y_adm_info_baseline_['src_subject_id'].isin(identifiers_abcd_train)
]

abcd_p_demo_filtered_tr = abcd_p_demo_baseline_[
    abcd_p_demo_baseline_['src_subject_id'].isin(identifiers_abcd_train)
]

# --- Step 3: Merge the filtered AB-CD dataframes, select columns, and convert demo_sex_v2 values ---
# Merge the two filtered dataframes on 'src_subject_id'
merged3_abcd = pd.merge(abcd_mri_filtered_tr, abcd_p_demo_filtered_tr, on='src_subject_id', how='outer')

# Select only the columns of interest
merged3_abcd = merged3_abcd[['src_subject_id', 'mri_info_manufacturer', 'mri_info_manufacturersmn', 'demo_sex_v2']]

# Map numeric demo_sex_v2 values to gender labels
sex_mapping = {1: "Male", 2: "Female", 3: "Other"}
merged3_abcd['demo_sex_v2'] = merged3_abcd['demo_sex_v2'].map(sex_mapping)

# %%
# new column by concatenating the two existing columns 
merged2_abcd['mri_info_manufacturer_model'] = (
    merged2_abcd['mri_info_manufacturer'].astype(str) +
    " | " +
    merged2_abcd['mri_info_manufacturersmn'].astype(str)
)

# Create a dictionary mapping "src_subject_id" to "mri_info_manufacturer".
abcd_inlier_scanner_dict = merged2_abcd.set_index("src_subject_id")["mri_info_manufacturer_model"].to_dict()

# Create a dictionary mapping "src_subject_id" to "demo_sex_v2".
abcd_inlier_sex_dict = merged2_abcd.set_index("src_subject_id")["demo_sex_v2"].to_dict()

# %%
# new column by concatenating the two existing columns 
merged3_abcd['mri_info_manufacturer_model'] = (
    merged3_abcd['mri_info_manufacturer'].astype(str) +
    " | " +
    merged3_abcd['mri_info_manufacturersmn'].astype(str)
)

# Create a dictionary mapping "src_subject_id" to "mri_info_manufacturer".
abcd_inlier_scanner_dict = merged3_abcd.set_index("src_subject_id")["mri_info_manufacturer_model"].to_dict()

# Create a dictionary mapping "src_subject_id" to "demo_sex_v2".
abcd_inlier_sex_dict = merged3_abcd.set_index("src_subject_id")["demo_sex_v2"].to_dict()

# %%
merged2_abcd_val = merged2_abcd[merged2_abcd['src_subject_id'].isin(identifiers_abcd_val)]
merged2_abcd_test = merged2_abcd[merged2_abcd['src_subject_id'].isin(identifiers_abcd_test)]
merged2_abcd_val.shape, merged2_abcd_test.shape
# Out:
# ((127, 5), (125, 5))

# %%
merged3_abcd[merged3_abcd['src_subject_id'].isin(identifiers_abcd_train)].shape
# Out:
# (976, 5)

# %%
merged2_abcd_val['mri_info_manufacturer_model'].value_counts(), "========" , merged2_abcd_val['demo_sex_v2'].value_counts()
# Out:
# (mri_info_manufacturer_model
#  SIEMENS | Prisma_fit                         54
#  SIEMENS | Prisma                             51
#  GE MEDICAL SYSTEMS | DISCOVERY MR750         18
#  Philips Medical Systems | Achieva dStream     2
#  Philips Medical Systems | Ingenia             2
#  Name: count, dtype: int64,
#  '========',
#  demo_sex_v2
#  Female    70
#  Male      56
#  Other      1
#  Name: count, dtype: int64)

# %%
merged2_abcd_test['mri_info_manufacturer_model'].value_counts(), "========" , merged2_abcd_test['demo_sex_v2'].value_counts()
# Out:
# (mri_info_manufacturer_model
#  SIEMENS | Prisma_fit                         50
#  SIEMENS | Prisma                             44
#  GE MEDICAL SYSTEMS | DISCOVERY MR750         17
#  Philips Medical Systems | Achieva dStream     7
#  Philips Medical Systems | Ingenia             6
#  nan | nan                                     1
#  Name: count, dtype: int64,
#  '========',
#  demo_sex_v2
#  Male      65
#  Female    60
#  Name: count, dtype: int64)

# %%
merged3_abcd['mri_info_manufacturer_model'].value_counts(), "========" , merged3_abcd['demo_sex_v2'].value_counts()
# Out:
# (mri_info_manufacturer_model
#  SIEMENS | Prisma_fit                         394
#  SIEMENS | Prisma                             331
#  GE MEDICAL SYSTEMS | DISCOVERY MR750         144
#  Philips Medical Systems | Achieva dStream     66
#  Philips Medical Systems | Ingenia             38
#  nan | nan                                      3
#  Name: count, dtype: int64,
#  '========',
#  demo_sex_v2
#  Female    533
#  Male      443
#  Name: count, dtype: int64)

# %%
hcd_metadata = pd.read_csv("spreadsheets/HCD_LS_2.0_subject_completeness.csv")

# %%
hcd_metadata
# Out:
#             src_subject_id        subjectkey  \
# 0    HCA or HCD subject id       Pseudo-Guid
# 1               HCD0001305  NDAR_INVEE728YNM
# 2               HCD0008117  NDAR_INVKH253JC7
# 3               HCD0021614  NDAR_INVCY281KJ2
# 4               HCD0022919  NDAR_INVXF194BDK
# ..                     ...               ...
# 648             HCD2982579  NDAR_INVNC447ATF
# 649             HCD2987185  NDAR_INVAX000CBL
# 650             HCD2990073  NDAR_INVDR796KTJ
# 651             HCD2993079  NDAR_INVGG441MM6
# 652             HCD2996590  NDAR_INVGK026LCR
#
#                                         interview_date  interview_age  \
# 0    RedCap event registration date when copied to ...  age in months
# 1                                              10/1/17            143
# 2                                               4/1/19            192
# 3                                               7/1/18            110
# 4                                               7/1/18            117
# ..                                                 ...            ...
# 648                                             1/1/19            225
# 649                                             4/1/18            175
# 650                                             7/1/18            163
# 651                                            10/1/18            194
# 652                                             4/1/18            237
#
#               sex                visit  \
# 0    sex at birth  subject visit/event
# 1               M                   V1
# 2               F                   V1
# 3               F                   V1
# 4               F                   V1
# ..            ...                  ...
# 648             F                   V1
# 649             M                   V1
# 650             F                   V1
# 651             F                   V1
# 652             M                   V1
#
#                                unrelated_subset  \
# 0    Is subject unrelated to others in HCA/HCD?
# 1                                          TRUE
# 2                                          TRUE
# 3                                          TRUE
# 4                                          TRUE
# ..                                          ...
# 648                                        TRUE
# 649                                        TRUE
# 650                                        TRUE
# 651                                       FALSE
# 652                                        TRUE
#
#                                    Full_MR_Compl        T1_Count  \
# 0    Full MR protocol 100% complete? 1=Yes, 2=No  # of T1w scans
# 1                                              1               1
# 2                                              1               1
# 3                                              1               1
# 4                                              1               1
# ..                                           ...             ...
# 648                                            1               1
# 649                                            1               1
# 650                                            1               1
# 651                                            1               1
# 652                                            1               1
#
#            T2_Count  ...                            tlbx_socwit01  \
# 0    # of T2w scans  ...  Any data in tlbx_socwit01? 1=yes, 0=no
# 1                 1  ...                                        1
# 2                 1  ...                                        0
# 3                 1  ...                                        1
# 4                 1  ...                                        1
# ..              ...  ...                                      ...
# 648               1  ...                                        0
# 649               1  ...                                        0
# 650               1  ...                                        0
# 651               1  ...                                        0
# 652               1  ...                                        0
#
#                                tlbx_wellbeing01  \
# 0    Any data in tlbx_wellbeing01? 1=yes, 0=no
# 1                                             1
# 2                                             0
# 3                                             1
# 4                                             1
# ..                                          ...
# 648                                           1
# 649                                           0
# 650                                           1
# 651                                           0
# 652                                           1
#
#                                tpvt01                            upps01  \
# 0    Any data in tpvt01? 1=yes, 0=no   Any data in upps01? 1=yes, 0=no
# 1                                   1                                 1
# 2                                   0                                 1
# 3                                   1                                 1
# 4                                   1                                 1
# ..                                ...                               ...
# 648                                 1                                 1
# 649                                 0                                 1
# 650                                 1                                 1
# 651                                 0                                 1
# 652                                 1                                 1
#
#                                vision_tests01  \
# 0    Any data in vision_tests01? 1=yes, 0=no
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
# ..                                        ...
# 648                                         1
# 649                                         1
# 650                                         1
# 651                                         1
# 652                                         1
#
#                                vitals01  \
# 0    Any data in vitals01? 1=yes, 0=no
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1
# ..                                  ...
# 648                                   1
# 649                                   1
# 650                                   1
# 651                                   1
# 652                                   1
#
#                                wais_iv_part101  \
# 0    Any data in wais_iv_part101? 1=yes, 0=no
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ..                                         ...
# 648                                          1
# 649                                          0
# 650                                          0
# 651                                          0
# 652                                          1
#
#                                wisc_v01                            wppsiiv01  \
# 0    Any data in wisc_v01? 1=yes, 0=no   Any data in wppsiiv01? 1=yes, 0=no
# 1                                     1                                    0
# 2                                     1                                    0
# 3                                     1                                    0
# 4                                     1                                    0
# ..                                  ...                                  ...
# 648                                   0                                    0
# 649                                   1                                    0
# 650                                   1                                    0
# 651                                   1                                    0
# 652                                   0                                    0
#
#                                ysr01
# 0    Any data in ysr01? 1=yes, 0=no
# 1                                  1
# 2                                  1
# 3                                  0
# 4                                  0
# ..                               ...
# 648                                0
# 649                                1
# 650                                1
# 651                                1
# 652                                0
#
# [653 rows x 85 columns]

# %%
def count_hcp_sex(id_list, metadata_df):
    # Filter IDs starting with "HCP"
    hcp_ids = [sid for sid in id_list if sid.startswith("HCD")]
    # Select rows in metadata matching those IDs
    df_hcp = metadata_df[metadata_df["src_subject_id"].astype(str).isin(hcp_ids)]
    # Count by sex
    return df_hcp["sex"].value_counts()

# Compute for each split
train_sex_counts = count_hcp_sex(identifiers_abcd_train, hcd_metadata)
val_sex_counts   = count_hcp_sex(identifiers_abcd_val,   hcd_metadata)
test_sex_counts  = count_hcp_sex(identifiers_abcd_test,  hcd_metadata)

# Combine into a summary DataFrame
summary_df = pd.concat(
    [train_sex_counts.rename("TRAIN"),
     val_sex_counts.rename("VAL"),
     test_sex_counts.rename("TEST")],
    axis=1
).fillna(0).astype(int)

print(summary_df)
# Out:
#      TRAIN  VAL  TEST
# sex
# F      178   15    28
# M      163   22    12
